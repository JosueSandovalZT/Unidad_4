# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueSandovalZT/Unidad_4/blob/main/integracion_tipo_Gaussiana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aplicacion IA : integracion tipo Gaussiana

# %%
import numpy as np # importa numpy

def f(x,y): #Define funcion tipo gaussiana
  return np.exp(-(x**2 + y**2)) #calcula

a,b = -1,1 # intervalo en x
c,d = -1,1 #intervalo en y

n = 100 #numero de divisiones en x
m = 100 # nunmero de divisiones en y

dx = (b-a)/n #paso en x
dy = (d-c)/m # paso en y

integral = 0 # inicializa acumulador

for i in range(n): #itera en x
  for j in range(m): # itera en y

    x = a + i*dx # calcula punto en x
    y = c + j*dy #calcula punto en y

    integral += f(x,y)*dx*dy #acumula contribucion

print("Probabilidad aproximada : ",integral)
# Out:
# Probabilidad aproximada :  2.2308386131926694
