# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueSandovalZT/Unidad_4/blob/main/Diferencia_hacia_adelante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diferencia hacia adelante

# %%
import numpy as np # importa la bibloteca numpy para calculos numericos

def f(x): #define la funcion matematica a analizar
  return x**3 #retorna el valor de la funcion x 3

x = 2 # punto donde se calculara la derivada

h = 0.001 #tamaño del paso numerico

derivada = (f(x+h)-f(x))/h # aplica la formula de diferencia hacia adelante

real = 3*x**2 #calcula la derivada analitica real

error = abs(real - derivada) # calcuña el error absoluto

print("Deriada numerica:" ,derivada) # muestra el valor aproximado

print("derivada real : ",real) # muestra el valor exacto

print("Error : ",error) # muestra la diferencia entre valores
# Out:
# Deriada numerica: 12.006000999997823
# derivada real :  12
# Error :  0.006000999997823442
